# %% [markdown]
# ### Exercise 5: Subplot Layout

# %%
# TASK: Create a 2x2 subplot layout.
# Plot a line chart in the first subplot, a bar chart in the second, a scatter plot in the third, and a pie chart in the fourth.

# %%
import matplotlib.pyplot as plt
import numpy as np

#Data for plots
x=np.linspace(0,10,100)
y=x**2

categories=['A','B','C','D']
values=[5,7,3,9]

pie_labels=['Python','Java','C++','JavaScript']
pie_sizes=[40,25,20,15]

#Create a 2x2 subplot layout
fig, axs=plt.subplots(2,2,figsize=(10,8))

#First subplot: Line chart
axs[0,0].plot(x,y)
axs[0,0].set_title("Line Chart: y=x^2")

#Second subplot: Bar chart
axs[0,1].bar(categories, values, color=['red','blue','green','purple'])
axs[0,1].set_title("Bar Chart")

#Third subplot: Scatter plot
axs[1,0].scatter(x[:5],y[:5])
#Using first 5 points for simplicity
for i in range(5):
    axs[1,0].annotate(f"({x[i]:.1f},{y[i]:.1f})",(x[i],y[i]),textcoords="offset points",xytext=(0,5),ha='center')
axs[1,0].set_title("Scatter Plot with Annotations")

#Fourth subplot: Pie chart
axs[1,1].pie(pie_sizes,labels=pie_labels,autopct='%1.1f%%')
axs[1,1].set_title("Pie Chart")

#Adjust layout for better spacing
plt.tight_layout()

#Display the plots
plt.show()
